# %% [markdown]
# ## Task 1: Data Exploration, Pre-Processing and Augmentation
#
# In this task, you will create a pipeline to load and transform your training, validation, and test data. Create a Jupyter notebook named `preprocessing.ipynb`, implementing the requirements below.
#
# ### 1. Loading the data
# - Create the dataset based on the `KneeOA` folder.
# - Load the images as tensors. Note that the images are provided as `.png` files, which are typically loaded with three channels (RGB). However, since these are grayscale X-ray images, the three channels are identical. Hence, the inputs can be simplified to a single channel. Note that some pretrained models used in Task 3 do require three input channels, so you may have to adapt your dataset later on.
#
# ### 2. Data Exploration
# - Print the size of the training, validation, and test sets.
# - Show the distribution of the classes.
# - Plot a few samples from each class with their corresponding labels.
# - Explore and display statistics on the pixel intensities (e.g., pixel average, global average, pixel standard deviation, global standard deviation, ...).
#
# ### 3. Pre-processing
# - Check the original image size. Downsample the images by resizing them to 128 × 128 pixels. This decreases the image resolution and loses some information. Nevertheless, it lowers the computational requirements in future steps.
# - Implement a normalization strategy using fixed values, sample statistics, or the statistics of the training dataset, and test it on a sample from the validation dataset.
#
# ### 4. Augmentation
# - Implement at least two different relevant types of data augmentation.
# - Visualize the transformations on a sample from the training dataset, both individually and combined.
#
# ### 5. Pipeline
# - Implement the full pipeline for preprocessing and data augmentation for the next tasks.
# - Reflect on whether data augmentation should be applied to the validation and test sets.
#
# ---
#
# In your report, provide a detailed discussion of the dataset and the preprocessing steps you implemented, addressing the following aspects:
#
# - **Dataset:** Clearly discuss the dataset used and its statistics.
# - **Classification challenges:** Discuss the intrinsic difficulties of the dataset and its distribution for the classification task. This includes, for example, the observed image variability and class distribution.
# - **Image handling:** Discuss how you preprocessed your images. This includes the chosen normalization and data augmentation. Clearly motivate your choices.

# %% [markdown]
# ----
# ----

# %% [markdown]
# ## Setup

# %%
# install dependencies
# You can run this directly here or in your terminal (without the !)
#!pip install -r ../0_generalcode/requirements.txt

# %%
# import external modules
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image, ImageStat
import numpy as np
import sys
import pandas as pd

# %%
# We need to work with torch; so try to set the GPU backend for that.


sys.path.insert(0, "../0_generalcode")
from gpu_helper import settest_torch_gpu

settest_torch_gpu()
# Out:
# PyTorch CUDA available: True
# GPU: NVIDIA GeForce RTX 4070 Laptop GPU
# Keras backend: tensorflow
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Prediction shape: (5, 1)  — Keras is running on tensorflow , device: cuda
# 'cuda'

# %% [markdown]
# ## First visual exploration
# A visual inspection in the file explorer shows that there are some variations in the input images.
#
# We see variations in lighting (light,medium, dark); although the displaying in notebook shows less difference between medium and dark.
# There are also some images which appear to have more details than others.
# => this indicates the need for augmentation on these aspects.
#
# A minority of the samples show foreign objects (screws/plates/overlays). detailed model inspection needed to see if these objects influence the result.
#
# - trainset: 500 (0) / 250(1) -> watch out for false negatives (overfitting on class 0) ?
#
# Intuitive steps to take:
# - few samples with bolts&plates, but they seem equaly distibuted over classes (0/1) -> check later if this presents issues (delete these from training ?)
# - vertical flip; All image are left or rith samples, there is no influence on the classification, so we could flip them during training. (This would not be possible with e.g. torso-xray where left/right does make a difference)
# - small rotations, shifts needed ?
# - resize to 128x128 - on all sets (train/validate/test)
# - light intensity augmentation (there are clearly images with different intensity) !
# - noise/blur ?
# - tensor / normalization

# %%
def plot_images(image_paths, titles=None, max_cols=4) -> None:
    n = len(image_paths)
    cols = min(n, max_cols)
    rows = -(-n // cols)  # ceiling division

    fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows), squeeze=False)
    axes = [ax for row in axes for ax in row]

    for i, ax in enumerate(axes):
        if i < n:
            img = mpimg.imread(image_paths[i])
            ax.imshow(img, cmap="gray")
            if titles:
                ax.set_title(titles[i])
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %%
images = [
    "../../data/1_source/train/0/9003126L.png",
    "../../data/1_source/train/1/9075815L.png",
    "../../data/1_source/train/0/9102958R.png",
    "../../data/1_source/train/1/9053047L.png",
    "../../data/1_source/train/1/9529676R.png",
]
titles = ["Light", "Medium", "Dark", "Detailed", "Foreign Objects"]

plot_images(images, titles)

# %% [markdown]
# ## Dataset validation & inspection
# - validation of images
# - distributions
# - pixel evaluation
#
#
# First gather all the file information in a datastructure. This data structure can lateron be used to process all files.

# %%
from img_helper import make_image_dataframe

images_df = make_image_dataframe(src_path="../../data/1_source")

print(images_df.head())
# Out:
#    split label      filename       id side   folder img_format    img_size  \
# 0  train     0  9001695L.png  9001695    L  train/0        PNG  (224, 224)
# 1  train     0  9001897L.png  9001897    L  train/0        PNG  (224, 224)
# 2  train     0  9003126L.png  9003126    L  train/0        PNG  (224, 224)
# 3  train     0  9003126R.png  9003126    R  train/0        PNG  (224, 224)
# 4  train     0  9003430L.png  9003430    L  train/0        PNG  (224, 224)
#
#   img_mode img_info
# 0        L       {}
# 1        L       {}
# 2        L       {}
# 3        L       {}
# 4        L       {}

# %% [markdown]
# #### Foreign objects or fotofilm markings.
# Since these properties migth might influence the classifier, we want to keep track of them.
# If this does influence the classification, we could opt to drop these from the training set and thus reducing our context/complexity.
#
# In this case (few samples) we Identified these manually. In real-life one might need to setup a separate classifier to identify foreign objects first. So we could use the result from that "foreign object classifier" as an input for the 0/1 classifier.

# %%
foreign_objects = {
    ("train/0", "9082640L.png"),
    ("train/0", "9160026L.png"),
    ("train/0", "9170536L.png"),
    ("train/1", "9008322L.png"),
    ("train/1", "9065272L.png"),
    ("train/1", "9070442L.png"),
    ("train/1", "9425996L.png"),
    ("train/1", "9510943L.png"),
    ("train/1", "9529676R.png"),
    ("val/0", "9031141L.png"),
    ("val/1", "9375300L.png"),
    ("val/1", "9387265L.png"),
    ("test/1", "9087632L.png"),
    ("test/1", "9559547R.png"),
    ("test/1", "9688649L.png"),
}

images_df["foreign_objects"] = (
    images_df[["folder", "filename"]]
    .apply(tuple, axis=1)
    .isin(foreign_objects)
    .astype(int)
)

images_df
# Out:
#       split label      filename       id side   folder img_format    img_size  \
# 0     train     0  9001695L.png  9001695    L  train/0        PNG  (224, 224)
# 1     train     0  9001897L.png  9001897    L  train/0        PNG  (224, 224)
# 2     train     0  9003126L.png  9003126    L  train/0        PNG  (224, 224)
# 3     train     0  9003126R.png  9003126    R  train/0        PNG  (224, 224)
# 4     train     0  9003430L.png  9003430    L  train/0        PNG  (224, 224)
# ...     ...   ...           ...      ...  ...      ...        ...         ...
# 1050   test     1  9610439R.png  9610439    R   test/1        PNG  (224, 224)
# 1051   test     1  9632586R.png  9632586    R   test/1        PNG  (224, 224)
# 1052   test     1  9669124R.png  9669124    R   test/1        PNG  (224, 224)
# 1053   test     1  9688649L.png  9688649    L   test/1        PNG  (224, 224)
# 1054   test     1  9690658R.png  9690658    R   test/1        PNG  (224, 224)
#
# ...

# %% [markdown]
# ### Validations
# **Input validation**
# We are given a dataset of grayscale PNG, sized 228*228. Doublecheck these settings.
#
# **Leakage detection**
# There are images denoted with R (right knee/foto) and L (right knee/foto). Are there images from same knee or person (both left and right) ? If so are these not scattered accross our sets (train/val/test) ?

# %%
print("Input validation")
images_df[["img_format", "img_size", "img_mode"]].value_counts().reset_index(
    name="count"
)
# Out:
# Input validation
#   img_format    img_size img_mode  count
# 0        PNG  (224, 224)        L   1055

# %% [markdown]
# All images have the same format, size and mode (grayscale) accross all splits.

# %%
# Check if any id appears multiple times
print("Leakage detection")
dup_detail = images_df.groupby(["id"]).size().reset_index(name="count")
cnt_dup_detail = dup_detail[dup_detail["count"] > 1]

if len(cnt_dup_detail) == 0:
    print("ID's are unique.")
else:
    print(f"{len(cnt_dup_detail)} IDs are not unique.")

    # Check if any id appears in more than one split (data leakage check)
    id_splits = images_df.groupby("id")["split"].nunique()
    leaked_ids = id_splits[id_splits > 1].index

    if len(leaked_ids) == 0:
        print("No ID overlap across splits.")
    else:
        print(f"{len(leaked_ids)} IDs appear in multiple splits:")
        print(
            images_df[images_df["id"].isin(leaked_ids)][
                ["id", "split", "side", "label"]
            ].sort_values("id")
        )
# Out:
# Leakage detection
# 334 IDs are not unique.
# No ID overlap across splits.

# %% [markdown]
# The IDs we extract from a filename are not unique. We need to take this into account when generating new augmented files. It is always a good idea to make sure you can trace back any derived sample (images in this case) to its original sample.
# We will do this by using suffixes on the filenames of derived images.

# %% [markdown]
# ### Distributions
# Distributions to check:
#
# - Input distribution (L/R).
# - Class distribution (0/1).

# %%
print("Class distribution")
counts = images_df.groupby(["split", "label"]).size().unstack()
proportions = counts.div(counts.sum(axis=1), axis=0).round(2)
pd.concat([counts, proportions], axis=1, keys=["count", "proportion"])
# Out:
# Class distribution
#       count      proportion
# label     0    1          0     1
# split
# test     96   50       0.66  0.34
# train   500  250       0.67  0.33
# val      96   63       0.60  0.40

# %%
print("Left/Right distribution")
counts = images_df.groupby(["split", "side"]).size().unstack()
proportions = counts.div(counts.sum(axis=1), axis=0).round(2)
pd.concat([counts, proportions], axis=1, keys=["count", "proportion"])
# Out:
# Left/Right distribution
#       count      proportion
# side      L    R          L     R
# split
# test     75   71       0.51  0.49
# train   385  365       0.51  0.49
# val      82   77       0.52  0.48

# %% [markdown]
# - **Input distribution** over L and R is near even. No actions needed here.
#
# - There is no heavy **class imbalance** between labels 0 and 1; minority class (1) is above 30% in all the splits. The class distribution accross the splits itself is even. So no extra steps needed in data augmentation to address this. We might need to this into account in the model evaluation.
#
# **Options for dealing with small class imbalance:**
# - class weigths in the model
# - model metrics: F1-score / recall on class 1
#
# Changing the class balance with a data modification will give a false representation of the real-world scenario and is thus not a good approach. In the real world we will also see more XRAYS of healthy cases then osteoarthritis cases.

# %% [markdown]
# ### Pixel Statistics
# Explore pixel value distributions per split and class. Pixel values are in [0, 255] (uint8 grayscale).
# - **Global mean / std**: computed across all pixels in a group (exact, via running sums)
# - **Avg image mean / std**: average of per-image statistics — reveals how much brightness varies across images
#
# **Brightness proxy**: per-image pixel mean — higher mean = brighter image.
#
# **Contrast proxies**:
# - *Pixel std*: spread of intensity values within an image — higher std = more contrast.
# - *Dynamic range* (max − min): captures exposure extremes; X-rays with narrow range may look flat/low-contrast.
#
# Both brightness and contrast vary across the dataset (visible in the earlier sample plots), motivating the brightness (±10%) and contrast (±15%) augmentations.

# %%
src_path = "../../data/1_source"


def per_image_stats(row):
    path = Path(src_path) / row["folder"] / row["filename"]
    with Image.open(path) as im:
        stat = ImageStat.Stat(im)
    return pd.Series(
        {
            "pixel_mean": stat.mean[0],
            "pixel_std": stat.stddev[0],
            "pixel_min": stat.extrema[0][0],
            "pixel_max": stat.extrema[0][1],
            "dynamic_range": stat.extrema[0][1] - stat.extrema[0][0],
            "pixel_sum": stat.sum[0],
            "pixel_sq_sum": stat.sum2[0],
            "pixel_count": stat.count[0],
        }
    )


pixel_df = images_df.apply(per_image_stats, axis=1)
images_stats_df = pd.concat([images_df[["split", "label", "side"]], pixel_df], axis=1)


# Exact global mean and std per split+label (via running sums)
def exact_global_stats(grp):
    n = grp["pixel_count"].sum()
    mean = grp["pixel_sum"].sum() / n
    std = np.sqrt(grp["pixel_sq_sum"].sum() / n - mean**2)
    return pd.Series(
        {
            "n_images": len(grp),
            "global_mean (brightness)": round(mean, 2),
            "global_std (contrast)": round(std, 2),
            "avg_image_mean": round(grp["pixel_mean"].mean(), 2),
            "std_image_mean": round(grp["pixel_mean"].std(), 2),
            "avg_image_std": round(grp["pixel_std"].mean(), 2),
            "std_image_std": round(grp["pixel_std"].std(), 2),
            "avg_dynamic_range": round(grp["dynamic_range"].mean(), 2),
            "std_dynamic_range": round(grp["dynamic_range"].std(), 2),
        }
    )


summary = images_stats_df.groupby(["split", "label"]).apply(exact_global_stats)
summary
# Out:
#              n_images  global_mean (brightness)  global_std (contrast)  \
# split label
# test  0          96.0                    154.13                  47.81
#       1          50.0                    165.62                  50.72
# train 0         500.0                    152.89                  49.74
#       1         250.0                    158.03                  49.48
# val   0          96.0                    157.93                  50.99
#       1          63.0                    160.81                  54.47
#
#              avg_image_mean  std_image_mean  avg_image_std  std_image_std  \
# split label
# test  0              154.13           24.55          38.71          13.88
#       1              165.62           22.77          43.31          13.88
# train 0              152.89           25.58          39.99          14.92
#       1              158.03           27.40          38.20          15.56
# ...

# %%
train_stats = images_stats_df[images_stats_df["split"] == "train"]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Per-image mean distribution by class
for label, color, name in [("0", "steelblue", "No OA (0)"), ("1", "salmon", "OA (1)")]:
    subset = train_stats[train_stats["label"] == label]["pixel_mean"]
    axes[0].hist(subset, bins=30, alpha=0.6, color=color, label=name)
axes[0].set_title("Distribution of per-image pixel mean (train)")
axes[0].set_xlabel("Mean pixel intensity (brithness proxy)")
axes[0].set_ylabel("Number of images")
axes[0].legend()

# Per-image std distribution by class
for label, color, name in [("0", "steelblue", "No OA (0)"), ("1", "salmon", "OA (1)")]:
    subset = train_stats[train_stats["label"] == label]["pixel_std"]
    axes[1].hist(subset, bins=30, alpha=0.6, color=color, label=name)
axes[1].set_title("Distribution of per-image pixel std (train)")
axes[1].set_xlabel("Pixel std (contrast proxy)")
axes[1].set_ylabel("Number of images")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Augmentations & preprocessing pipeline
# - https://pillow.readthedocs.io/en/stable/handbook/concepts.html  indicates LANCZOS as the best resampling filter for downscaling quality.
# - we write downsampled images into a new folder with the same structure as the original source folder
# The idea is to generate several stored versions of the source dataset. Each of which can be read by the next notebooks. The results can then be compared in the model evaluation step.
#
# Once the best version is established the other versions can be dropped.
# In practice one would/could do all the augmentation and scaling steps in memory as well; but this depend on the problem/data_volumes/available gpu,cpu,storage / etc.

# %%
from img_helper import generate_imageset, resample_xray, save_xray


def img_subsample(input_path, output_path):
    with Image.open(input_path) as im:
        im = resample_xray(im)
        save_xray(im, output_path)


# subsample all splits (train, val, test)
generate_imageset(
    images_frame=images_df,
    src_path="../../data/1_source",
    dst_path="../../data/2_downsampled",
    file_suffix="subs",
    conversion_function=img_subsample,
    only_train_split=False,
    initialize_target=True,
)

# %% [markdown]
# ### Normalization
#
# We normalize using the **training set statistics** (mean and std computed over all training pixels).
# This is preferred over fixed values (e.g. 0.5/0.5) or per-sample statistics because:
# - It uses the actual data distribution, not an arbitrary assumption.
# - Applying training statistics to val/test avoids leaking information from those sets.
# - Per-sample normalization would remove genuine brightness differences between images, losing a potentially informative signal.
#
# Two transforms are defined:
# - **`preprocess`** — val and test: Grayscale → Resize → ToTensor → Normalize.
# - **`train_transform`** — training: same as above but with online augmentation inserted before ToTensor.
#
# `images_stats_df` already contains `pixel_sum`, `pixel_sq_sum` and `pixel_count` per image,
# so we derive exact global statistics without re-scanning the files.
# After `ToTensor()`, pixel values are in [0, 1], so we divide the [0, 255] stats by 255.

# %%
import torch
from torchvision import transforms

# Compute exact train mean/std from already-gathered pixel sums (avoids re-scanning)
train_rows = images_stats_df[images_stats_df["split"] == "train"]
n = train_rows["pixel_count"].sum()
train_mean_255 = train_rows["pixel_sum"].sum() / n
train_std_255 = np.sqrt(train_rows["pixel_sq_sum"].sum() / n - train_mean_255**2)

train_mean = float(train_mean_255 / 255.0)
train_std = float(train_std_255 / 255.0)
print(f"Train mean (scaled to [0,1]): {train_mean:.4f}")
print(f"Train std  (scaled to [0,1]): {train_std:.4f}")

# Val/test: resize + normalize only — no augmentation
preprocess = transforms.Compose(
    [
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize(
            size=(128, 128),
            interpolation=transforms.InterpolationMode.BILINEAR,
            antialias=True,
        ),
        transforms.ToTensor(),
        transforms.Normalize(mean=[train_mean], std=[train_std]),
    ]
)

# Training: online augmentation applied every epoch before normalization
train_transform = transforms.Compose(
    [
        transforms.Grayscale(num_output_channels=1),
        transforms.RandomHorizontalFlip(),  # left/right knee are mirror images
        transforms.RandomAffine(
            degrees=5, translate=(0.03, 0.03)  # small rotation (+-5 degrees)
        ),  # small x/y shifts (+- 3%)
        transforms.transforms.Resize(
            size=(128, 128),
            interpolation=transforms.InterpolationMode.BILINEAR,
            antialias=True,
        ),
        transforms.ColorJitter(
            brightness=0.1, contrast=0.15  # exposure variation
        ),  # contrast variation
        transforms.ToTensor(),
        transforms.Normalize(mean=[train_mean], std=[train_std]),
    ]
)

# Test on one validation sample — show pixel distributions before and after normalization
val_sample = next(Path("../../data/1_source/val/0").glob("*.png"))

to_tensor = transforms.Compose(
    [
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize(
            size=(128, 128),
            interpolation=transforms.InterpolationMode.BILINEAR,
            antialias=True,
        ),
        transforms.ToTensor(),
    ]
)

with Image.open(val_sample) as im:
    original_t = to_tensor(im)
    normalized_t = preprocess(im)

print(f"\nVal sample: {val_sample.name}")
print(
    f"Original   — min={original_t.min():.3f}  max={original_t.max():.3f}  mean={original_t.mean():.3f}  std={original_t.std():.3f}"
)
print(
    f"Normalized — min={normalized_t.min():.3f}  max={normalized_t.max():.3f}  mean={normalized_t.mean():.3f}  std={normalized_t.std():.3f}"
)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes[0].imshow(original_t.squeeze(), cmap="gray")
axes[0].set_title(f"Val sample: {val_sample.name}")
axes[0].axis("off")
axes[1].hist(original_t.numpy().flatten(), bins=50, color="steelblue")
axes[1].set_title("Before normalization (ToTensor only)")
axes[1].set_xlabel("Pixel value [0, 1]")
axes[1].set_ylabel("Count")
axes[2].hist(normalized_t.numpy().flatten(), bins=50, color="salmon")
axes[2].set_title("After normalization (train mean/std)")
axes[2].set_xlabel("Pixel value (z-score)")
axes[2].set_ylabel("Count")
plt.suptitle("Normalization: effect on pixel distribution of a val sample")
plt.tight_layout()
plt.show()
# Out:
# Train mean (scaled to [0,1]): 0.6063
# Train std  (scaled to [0,1]): 0.1950
#
# Val sample: 9006140L.png
# Original   — min=0.082  max=0.969  mean=0.704  std=0.232
# Normalized — min=-2.688  max=1.859  mean=0.500  std=1.189

# %% [markdown]
# ### Augmentation Visualization
#
# **Part 1 — Individual transforms (PIL / img_helper):**
# Each augmentation op is applied in isolation to the same source image so the effect of each
# is clearly visible. This uses the `img_helper` PIL functions that were used in the offline approach.
#
# **Part 2 — Online augmentation (`train_transform`):**
# The same `train_transform` used during training is applied multiple times to one image.
# Because the ops are random, each call produces a different variant — this is the actual variety
# the model sees across epochs.

# %%
from img_helper import (
    transpose_xray,
    rotate_xray,
    brightness_xray,
    contrast_xray,
    resample_xray,
)

np.random.seed(42)

sample_path = "../../data/1_source/train/0/9003126L.png"

with Image.open(sample_path) as im:
    original = im.copy()

aug_samples = [
    ("Original", original),
    ("Flip (L/R)", transpose_xray(original, rnd=False)),
    ("Rotate (+-5 deg)", rotate_xray(original)),
    ("Brightness (+-10%)", brightness_xray(original)),
    ("Contrast (+-15%)", contrast_xray(original)),
    ("Resize 128x128", resample_xray(original)),
]

np.random.seed(42)
with Image.open(sample_path) as im:
    combined = transpose_xray(im, rnd=False)
    combined = rotate_xray(combined)
    combined = brightness_xray(combined)
    combined = contrast_xray(combined)
    combined = resample_xray(combined)
aug_samples.append(("Combined", combined))

fig, axes = plt.subplots(1, len(aug_samples), figsize=(4 * len(aug_samples), 4))
for ax, (title, img) in zip(axes, aug_samples):
    ax.imshow(img, cmap="gray")
    ax.set_title(title, fontsize=9)
    ax.axis("off")
plt.suptitle("Augmentation transforms applied to one training sample", fontsize=11)
plt.tight_layout()
plt.show()

# %%
# Display version of train_transform: identical ops but without Normalize
# (normalization changes the pixel scale, not the visual appearance)
train_transform_display = transforms.Compose(
    [
        transforms.Grayscale(num_output_channels=1),
        transforms.RandomHorizontalFlip(),
        transforms.RandomAffine(degrees=5),
        transforms.Resize(
            size=(128, 128),
            interpolation=transforms.InterpolationMode.BILINEAR,
            antialias=True,
        ),
        transforms.ColorJitter(brightness=0.1, contrast=0.15),
        transforms.ToTensor(),
    ]
)

sample_path = "../../data/1_source/train/0/9003126L.png"
n_variants = 6

fig, axes = plt.subplots(1, n_variants + 1, figsize=(4 * (n_variants + 1), 4))

# Original: resize only, no augmentation
with Image.open(sample_path) as im:
    original_t = transforms.Compose(
        [
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize(
                size=(128, 128),
                interpolation=transforms.InterpolationMode.BILINEAR,
                antialias=True,
            ),
            transforms.ToTensor(),
        ]
    )(im)
axes[0].imshow(original_t.squeeze(), cmap="gray")
axes[0].set_title("Original", fontsize=9)
axes[0].axis("off")

# Apply train_transform_display n_variants times — each call gives a different random result
for i in range(n_variants):
    with Image.open(sample_path) as im:
        aug_t = train_transform_display(im)
    axes[i + 1].imshow(aug_t.squeeze(), cmap="gray")
    axes[i + 1].set_title(f"Epoch variant #{i + 1}", fontsize=9)
    axes[i + 1].axis("off")

plt.suptitle(
    "Online augmentation: random variants produced by train_transform (one per epoch)",
    fontsize=11,
)
plt.tight_layout()
plt.show()

# %%
# Apply each torchvision transform individually to the same source image.
# Start from grayscale PIL so every op receives the same input type.
sample_path = "../../data/1_source/train/0/9003126L.png"

with Image.open(sample_path) as im:
    base = transforms.Grayscale(1)(im)  # PIL, single channel

named_transforms = [
    ("Original", transforms.Lambda(lambda x: x)),
    ("HorizontalFlip", transforms.RandomHorizontalFlip(p=1.0)),
    ("RandomAffine (+-5)", transforms.RandomAffine(degrees=5)),
    ("ColorJitter bri+10%", transforms.ColorJitter(brightness=(1.1, 1.1))),
    ("ColorJitter con+15%", transforms.ColorJitter(contrast=(1.15, 1.15))),
]

to_t = transforms.ToTensor()

fig, axes = plt.subplots(
    1, len(named_transforms), figsize=(4 * len(named_transforms), 4)
)
for ax, (title, t) in zip(axes, named_transforms):
    ax.imshow(to_t(t(base)).squeeze(), cmap="gray")
    ax.set_title(title, fontsize=9)
    ax.axis("off")

plt.suptitle("Online transforms applied individually (torchvision)", fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pipeline
#
# We use **online augmentation**: augmentation is applied randomly by the DataLoader each epoch
# via `train_transform`. Only the downsampled images (`data/2_downsampled/`) are needed on disk.
#
# | | **Online (chosen)** | **Offline (alternative)** |
# |---|---|---|
# | Augmentation | Randomly every epoch via `train_transform` | Once, saved to disk via `generate_imageset` |
# | Variety | New random variant every epoch | Fixed copies (3x per image) |
# | Disk usage | Only downsampled images | Extra ~3x train images |
# | Reproducibility | Stochastic (seed controls) | Deterministic |
#
# Normalization is always applied **at load time**, not baked into files.
# Val and test sets use `preprocess` (no augmentation, same training statistics).
#
# **Augmentation is not applied to val/test:** these sets must reflect real-world conditions
# without artificial variation, so that validation loss and test metrics are unbiased estimates
# of the model's true generalisation performance.

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

# All splits load from data/2_downsampled/
# train_transform: online augmentation + normalization
# preprocess:      normalization only (val/test must not be augmented)
train_dataset = datasets.ImageFolder(
    "../../data/2_downsampled/train", transform=train_transform
)
val_dataset = datasets.ImageFolder("../../data/2_downsampled/val", transform=preprocess)
test_dataset = datasets.ImageFolder(
    "../../data/2_downsampled/test", transform=preprocess
)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"Train samples : {len(train_dataset)}")
print(f"Val samples   : {len(val_dataset)}")
print(f"Test samples  : {len(test_dataset)}")
print(f"Classes       : {train_dataset.classes}")

# Sanity check: one batch shape and pixel range after normalization
imgs, labels = next(iter(train_loader))
print(f"Batch shape   : {imgs.shape}  (B, C, H, W)")
print(f"Pixel range   : [{imgs.min():.3f}, {imgs.max():.3f}]")
# Out:
# Train samples : 750
# Val samples   : 159
# Test samples  : 146
# Classes       : ['0', '1']
# Batch shape   : torch.Size([32, 1, 128, 128])  (B, C, H, W)
# Pixel range   : [-3.110, 2.020]
